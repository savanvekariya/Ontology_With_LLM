# %%
triplet subclass = {'limits': 'measure', 'load impedance': 'component', 'mppt': 'component', 'batteries': 'hardware component', 'hybrid energy system': 'system', 'power electronic circuit': 'hardware component', 'load': 'function', 'environmental concerns': 'objects', 'kw': 'unit', 'speed': 'measure', 'alternator pulley': 'hardware component', 'constant irradiance': 'measure', 'irradiance': 'measure', 'inductor current': 'measure', 'electrical device': 'hardware component', 'starter motor': 'hardware component', 'fuel prices': 'measure', 'lead acid battery': 'hardware component', 'vehicle': 'objects', 'power transfer': 'function', 'power versus voltage characteristics': 'measure', 'pv array': 'hardware component', 'voltage': 'measure', 'fig6': 'software', 'clutch': 'hardware component', 'huge amount for current': 'quantity', 'resistance': 'measure', 'energy supply': 'system', 'average output voltage': 'measure', 'inductor': 'component', 'fuel consumed': 'measure', 'battery management scheme': 'system', 'mppt dc-dc converter': 'hardware component', 'engine': 'component', 'proposed model': 'system', '12v lead acid battery': 'hardware component', 'placement of coil windings': 'function', 'series': 'objects', 'matlab/simulink': 'software', 'lead-acid battery': 'hardware component', 'combustion process': 'function', 'power rating': 'measure', 'solar cells': 'hardware component', 'starting system': 'system', 'convention system': 'system', 'source': 'component', 'huge current': 'measure', 'automotive system': 'system', 'coil windings': 'component', 'rotation': 'function', 'interface': 'component', 'power generated for solar': 'measure', 'mobile chargers': 'hardware component', 'maximum power point tracking charge controller': 'hardware component', 'cost': 'measure', 'system': 'system', 'location': 'place', 'single-diode electrical equivalent circuit': 'system', 'series resistor': 'component', 'charging': 'function', 'parameters': 'measure', "engine's gearbox housing": 'hardware component', 'battery': 'hardware component', 'solar pv module': 'hardware component', 'hybrid operation': 'function', 'operation': 'function', 'teeth of the flywheel': 'hardware subpart', 'power electronic component': 'component', 'condition of the switch': 'measure', 'charge': 'function', 'full bridge rectifier': 'hardware component', 'performance': 'measure', 'stator lead': 'hardware component', 'aes': 'software', 'photovoltaic systems': 'system', 'current source': 'hardware component', 'buck converter': 'hardware component', 'switch': 'hardware component', 'supply from the battery': 'function', 'battery soc': 'measure', 'self excitation': 'function', 'battery protection': 'function', 'unit cost': 'measure', 'pv system': 'system', 'dcdc converter': 'hardware component', 'factors of series and parallel no of cells': 'measure', 'fuel consumption': 'measure', 'mosfets': 'hardware component', 'extracting maximum power': 'function', 'diode': 'component', 'no self-discharge': 'function', 'crank the engine': 'function', 'charging system': 'system', 'car battery': 'hardware component', 'finite': 'function', 'operating mode buck converter': 'function', "car's electrical system": 'system', 'equivalent resistance': 'measure', 'peak power': 'measure', 'extra battery bank': 'hardware component', 'hybrid energy system for aes system': 'system', 'topologies': 'system', 'cranking': 'function', 'pinion': 'hardware component', 'various devices': 'objects', 'alternating magnetic field': 'component', 'stop and direct the flow of current': 'function', 'pinion gear flywheel': 'hardware component', 'mathematical equations': 'objects', 'current': 'measure', 'module': 'component', 'internal combustion engines': 'hardware component', 'input dc voltage': 'measure', 'fuel costs': 'measure', 'buck converter configuration': 'system', 'recharge': 'function', 'buck converter circuit': 'hardware component', 'bms': 'system', 'maximum power': 'measure', 'pv cell': 'hardware component', 'iron shaft': 'hardware component', '27 rs/hr': 'measure', 'fuel pump motor': 'hardware component', 'alternator model': 'hardware component', 'flexible thin-film solar pv module': 'hardware component', 'solenoid coils': 'hardware component', 'zero': 'quantity', 'stator': 'component', 'component': 'component', 'field voltage': 'measure', 'infinite': 'quantity', 'supply to the automotive loads': 'function', 'overall efficiency': 'measure', 'solar power': 'system', 'constant voltage source': 'hardware component', 'the two components': 'component', 'plunger': 'hardware component', 'photovoltaic array output power': 'measure', 'electrical and electronic accessories': 'objects', 'fuel indication': 'function', 'closed (on)': 'function', 'major power-related elements': 'hardware component', 'overview': 'function', 'two states': 'quantity', 'output': 'function', 'charge capacity': 'measure', 'storing of pv power': 'function', 'stator leads': 'hardware component', 'circuit': 'hardware component', '1000w/m2': 'measure', 'rotor': 'component', 'battery charge capacity': 'measure', 'duty cycle': 'measure', 'starter motor gear': 'hardware component', 'working principle': 'function', 'block': 'component', 'starter motor shaft': 'hardware component', 'variable irradiance values': 'measure', 'solar cell modelling equations': 'function', 'engine averaged model': 'system', 'car': 'objects', 'car tire diameter': 'measure', 'power generation': 'system', 'continuous mode': 'function', 'automotive electrical system': 'system', 'iron core': 'component', 'energy': 'measure', 'rooftop pv array': 'hardware component', 'operating modes': 'function', 'starter': 'hardware component', 'manage': 'function', 'continuous': 'measure', 'field voltage regulator': 'hardware component', 'one-way valve': 'hardware component', 'array': 'component', '120-degree intervals': 'measure', 'discontinuous': 'function', 'engine crank shaft': 'hardware component', 'convert supply from alternator from ac to dc': 'function', '270 rs/hr for 10 hours of operation': 'measure', 'dc motor': 'hardware component', 'dependability': 'measure', 'supply power': 'function', 'dc electricity': 'measure', 'parallel': 'function', 'dc-dc converters': 'hardware component', 'discontinuous mode': 'function', 'dc supply': 'hardware component', 'engine system': 'system', 'reducing fuel consumption': 'function', 'set of diodes': 'hardware component', 'ignition system': 'system', 'pv array modelling': 'function', 'lighting systems': 'system', 'alternating current': 'measure', 'electrical requirements': 'measure', '35 rs/hr': 'measure', 'stator windings': 'hardware component', 'electrical components': 'component', 'automotive': 'objects', 'battery charging': 'function', 'field winding': 'component', 'battery-rooftop pv array': 'hardware component', 'open (off)': 'function', 'maximize': 'function', 'fuel consumption display system': 'system', '5kw': 'unit', 'automotive alternator': 'hardware component', 'simulink model': 'software', 'solenoid': 'hardware component', 'diodes': 'component', 'ac current': 'measure', 'switch to the starter motor': 'hardware component', 'engine subsystem': 'system', 'mppt technique': 'function', 'project': 'objects', 'source voltage': 'measure', 'no aging': 'function', 'alternator': 'hardware component', 'solar panel': 'hardware component', 'rs/hr': 'measure', 'aes system': 'system', 'output load': 'component', 'shunt resistance': 'component', 'no dynamics': 'function', 'starter solenoid': 'hardware component'}
